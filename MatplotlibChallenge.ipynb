# %%
# Question #1 and part of #3

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('cces_example_data.csv', header = 0)

# %% [markdown]
# Question #2: The style that stands out to me is the Stack plot.  This provides a very interesting visual that shows the “parts” of the whole, much like a pie chart, but with an added element of time that allows for the “whole” to shrink or grow as the sum of the parts also shrinks or grows over time.   As a car lover, I would love to see the whole reflect total number of “registered” cars on the road in the U.S. and have the stacking values reflect things like sedans, SUVs, trucks, wagons, and so on.  There seems to be a massive movement towards larger vehicles (trucks and SUV’s)and I think this graph would help to prove or disprove my hypothesis of this shift.

# %%
df
# Out:
#      pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 0               2            6    2     2         1   56           6     1
# 1               2            4    2     5         1   53          13     1
# 2               1            2    1     2         1   69          10     2
# 3               2            3    1     6         1   76          97     1
# 4               4            5    2     6         1   83           4     1
# ..            ...          ...  ...   ...       ...  ...         ...   ...
# 654             1            5    2     2         2   30           4     1
# 655             2            2    1     4         1   19          97     1
# 656             4            6    1     3         1   20           7     1
# 657             2            2    1     3         1   23           5     2
# 658             2            2    1     3         1   23           5     2
#
# ...

# %%
# Question #3

df_clean = df.astype({'sex': 'category', 'pid3': 'category', 'nonwhite': 'category', 'Evaluation': 'category'})

# %%
# Question #4

fig1, ax1 = plt.subplots(1,2)
ax1[0].set_title('Age Histogram')
ax1[1].set_title('Political Identity')

#ax1.set_title("Question #4") - this failed - not sure if we can add a "fig" title?
# Out:
# Text(0.5, 1.0, 'Political Identity')

# %% [markdown]
# For the below qustions: I wanted to add some additional layers to this that were not coverd in our class session, I hope this is ok.

# %%
# Question #5

fig2, ax2 = plt.subplots(figsize=(12,5))

categories = df_clean.groupby("Evaluation").count()['caseid']
ax2.bar([0,1,2,3], categories, color=['pink', 'lime', 'aqua', 'yellow'], edgecolor=['red', 'green', 'blue', 'gold'], linewidth=2.0)

ax2.set_title("Question #5")
ax2.set_xlabel("Response Given")
ax2.set_ylabel("Number of People")

plt.show()

#ax2.set_xticks([0,1,2,3], ["good", "bad", "yes", "no"]) - Note: how to change "x" axis visual values

# %%
# Question #6

fix3, ax3 = plt.subplots()

ax3.scatter(df_clean['ConMediaUse'], df_clean['ImmiPhobia'],s=45, facecolor='fuchsia', edgecolor='indigo', alpha = .045)

ax3.set_xlabel("Conservative Media Use Value")
ax3.set_ylabel("Immigration Phobia Value")
ax3.set_title("Question #6")

plt.show()
